# %% [markdown]
# # Project 3 - Part 1, Git Practice, APS1070 Winter 2026
#
# **Deadline: March 4th, 17:00**
#
# **Academic Integrity**
#
# This project is individual - it is to be completed on your own. If you have questions, please post your query in the APS1070 Piazza Q&A forums (the answer might be useful to others!).
#
# Do not share your code with others, or post your work online. Do not submit code that you have not written yourself without proper acknowledgment of the source, including generated code (please refer to the course syllabus). Students suspected of plagiarism on a project, midterm or exam will be referred to the department for formal discipline for breaches of the Student Code of Conduct.

# %% [markdown]
# Please fill out the following:
#
#
# *   Your **name**:
# *   Your **student number**:

# %% [markdown]
# ## Part 1: Getting started with GitHub [2 Marks + 1.5 Marks Git Submission]

# %% [markdown]
# For the first four parts (Part 1-4) of this project, we will work on the [Climate Change: Earth Surface Temperature Dataset](https://www.kaggle.com/datasets/berkeleyearth/climate-change-earth-surface-temperature-data?select=GlobalLandTemperaturesByCountry.csv) which reports the monthly average temprature of over 200 countries worldwide. Download the dataset in .csv format using the provided code below.

# %%
import kagglehub
import pandas as pd
import numpy as np

path = kagglehub.dataset_download("berkeleyearth/climate-change-earth-surface-temperature-data")
df = pd.read_csv(filepath_or_buffer=path+'/GlobalLandTemperaturesByCountry.csv')

# %% [markdown]
# 1. Using the Pandas package, create a dataframe showing the `AverageTemperature` with the countries as rows and months from January 1901 to December 2012 as columns.
# Then, remove all the countries that have at least one missing or invalid value over the months. At the end, calculate the yearly average for each country from 1901 to 2012. The final dataframe should have the countries as rows and years as columns.
#  **[0.5]**
#
#
#     **hint:** your final dataframe will have a 234 x 112 shape.
#
#
# 2. Write a function which takes a dataframe and a list of countries as inputs, and plots time-series for all the countries in the list (it is best to plot each country in a separate graph (subplot), so you can easily compare them.)
#
# 3. Pick three countries whose names are closest to your first name using string edit distance.
#     **Hint:** you can use `Levenshtein.distance()` from the python-Levenshtein package. You may find [this link](https://www.geeksforgeeks.org/python/introduction-to-python-levenshtein-module/) helpful.
#
# 4. Apply `StandardScalar` to the data. Each month **(columns not rows)** should have a `mean` of zero and a `StD` of 1. **[0.5]**
#
# 5. Run the function in `step 1` on both the original dataset as well as the standardized dataset for the three countries you picked in `step 3` plus `Belgium`, `Canada`, and `Oman` (If you have already selected one of these countries, go down the list and pick the next one you haven't selected) **[0.5]**
#
# 6. Discuss the trends in the standardized time-series for all these countries. What does it mean if the curve goes up or down? What does the sign of values indicate? **[0.5]**

# %%
### YOUR CODE HERE ###
